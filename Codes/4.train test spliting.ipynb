# %% [markdown]
# # Import Necessary Libraries

# %%
import pandas as pd
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Generate Random Datasets To Practice

# %%
X, y = make_regression(n_samples=1000, n_features= 10, random_state= 69)

# %%
X
# Out:
# array([[-4.42382089e-01,  1.19113156e+00, -9.57998131e-01, ...,
#         -6.49694144e-01,  2.79074720e-01,  6.89181395e-01],
#        [-7.92393106e-01, -2.22110261e+00,  1.12234078e+00, ...,
#          7.02062020e-01, -2.27993402e+00,  3.39145596e-01],
#        [-2.49347016e-01,  1.55533807e-01,  1.00689610e+00, ...,
#          4.67075381e-01,  5.89229979e-02, -1.28513552e+00],
#        ...,
#        [ 3.88486095e-04,  2.57207854e-01, -7.84447616e-01, ...,
#         -1.07681952e+00, -4.12794182e-01,  9.23113111e-01],
#        [-1.44932767e-01, -2.22453455e-01,  7.36929256e-01, ...,
#         -3.53217465e-01, -1.96229734e-01,  6.12014631e-01],
#        [ 5.64108077e-01, -1.80169955e+00,  9.74529784e-01, ...,
#         -9.67621815e-01,  1.27956322e+00,  1.05312708e+00]],
#       shape=(1000, 10))

# %%
pd.DataFrame(X)
# Out:
#             0         1         2         3         4         5         6  \
# 0   -0.442382  1.191132 -0.957998 -0.418674 -1.999712 -0.835490 -0.719800
# 1   -0.792393 -2.221103  1.122341  0.906485  1.568781  0.834505  0.290596
# 2   -0.249347  0.155534  1.006896 -0.279695 -2.274622  0.052347 -0.349594
# 3    0.022602  0.357697 -0.700306 -1.393953 -0.651681  1.339827 -0.755715
# 4    0.460649  0.476359 -0.882323  0.311717 -0.551152 -0.631736 -0.577258
# ..        ...       ...       ...       ...       ...       ...       ...
# 995  0.523493  0.307082  2.053045  0.427419 -1.014546 -0.573331 -2.350406
# 996 -0.012894  0.081770  1.004227  0.209811  0.114674  0.917428  0.503098
# 997  0.000388  0.257208 -0.784448  0.567437  1.033269 -1.048167 -0.156414
# 998 -0.144933 -0.222453  0.736929  0.085722  0.932657 -1.306626 -0.006949
# 999  0.564108 -1.801700  0.974530 -0.080266 -0.563757 -1.315848  1.906928
#
#             7         8         9
# 0   -0.649694  0.279075  0.689181
# ...

# %% [markdown]
# # Spliting The Dataset into Training and Testing with Corresponding  Ratio 70 to 30

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= .30, random_state = 69)

# %%
X_train.shape
# Out:
# (700, 10)

# %%
y_train.shape
# Out:
# (700,)

# %%
X_test.shape
# Out:
# (300, 10)

# %%
y_test.shape
# Out:
# (300,)
