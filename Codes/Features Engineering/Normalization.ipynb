# %% [markdown]
# # **Normalization Process**

# %%
import pandas as pd
from sklearn.datasets import make_regression
from sklearn.preprocessing import MinMaxScaler

# %%
x, y = make_regression(n_samples= 1000,n_features = 5, random_state = 42, )

# %%
x.shape
# Out:
# (1000, 5)

# %%
print("Original Data:\n", x)
# Out:
# Original Data:
#  [[-1.03990593  0.61277391 -1.05341556 -0.62376896  1.91403135]
#  [ 0.31745326 -0.3328604  -0.09338686 -0.52933211 -1.51447031]
#  [ 0.53891004 -1.03724615 -0.19033868 -0.87561825 -1.38279973]
#  ...
#  [ 0.96539748  1.23613072  0.08865759  0.19731571 -0.6176519 ]
#  [ 0.64870989 -0.16711808  0.14671369  1.20650897 -0.81693567]
#  [-2.3919562   0.84477438 -0.00556029  1.17851269 -1.37340289]]

# %% [markdown]
# ## After Normalizing

# %%
normalizer = MinMaxScaler()
normalizeddata = normalizer.fit_transform(x,y)
print("ONormalized Data:\n", normalizeddata)
# Out:
# ONormalized Data:
#  [[0.30021429 0.57462167 0.3422088  0.39166323 0.72420258]
#  [0.49148153 0.42169257 0.49236992 0.40717898 0.23646757]
#  [0.52268729 0.30777847 0.47720538 0.35028497 0.25519889]
#  ...
#  [0.58278419 0.67543168 0.52084407 0.52656553 0.36404801]
#  [0.53815933 0.44849661 0.52992481 0.69237365 0.33569811]
#  [0.10969515 0.61214106 0.50610715 0.68777392 0.25653567]]
